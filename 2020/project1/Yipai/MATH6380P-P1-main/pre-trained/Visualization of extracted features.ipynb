# %% [markdown]
# # Visualization of features extracted by pre- trained deep neural networks

# %%
from utils import *

# %% [markdown]
# ## Features extracted by pre-trained ResNet18

# %%
R_features, R_labels = get_stored_dataset("resnet", train=True)

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
visualize_LDA(R_features, R_labels)
plt.subplot(132)
visualize_PCA(R_features, R_labels)
plt.subplot(133)
visualize_TSNE(R_features, R_labels)

# %% [markdown]
# ## Features extracted by pre-trained VGG19

# %%
V_features, V_labels = get_stored_dataset("vgg19", train=True)

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
visualize_LDA(V_features, V_labels)
plt.subplot(132)
visualize_PCA(V_features, V_labels)
plt.subplot(133)
visualize_TSNE(V_features, V_labels)
